# %% [markdown]
# 观察events事件中有哪些技术动作

# %%
import readJson

events = []
for i in range(401468642, 401468800):
    jsonPath = f'./data/summary_{i}.json'
    events.extend(readJson.readEvents(path=jsonPath))
# for i in range(401468689, 401468692):
#     jsonPath = f'./data/summary_{i}.json'
#     events.extend(readJson.readEvents(path=jsonPath))
# for i in range(401468693, ):
#     jsonPath = f'./data/summary_{i}.json'
#     events.extend(readJson.readEvents(path=jsonPath))
print(len(events))
# Out:
# [json] json path:  ./data/summary_401468642.json
# [json] events number:  469
# [json] json path:  ./data/summary_401468643.json
# [json] events number:  560
# [json] json path:  ./data/summary_401468644.json
# [json] events number:  449
# [json] json path:  ./data/summary_401468645.json
# [json] events number:  510
# [json] json path:  ./data/summary_401468646.json
# [json] events number:  475
# [json] json path:  ./data/summary_401468647.json
# [json] events number:  480
# [json] json path:  ./data/summary_401468648.json
# [json] events number:  418
# [json] json path:  ./data/summary_401468649.json
# [json] events number:  462
# [json] json path:  ./data/summary_401468650.json
# [json] events number:  443
# [json] json path:  ./data/summary_401468651.json
# [json] events number:  513
# [json] json path:  ./data/summary_401468652.json
# [json] events number:  529
# [json] json path:  ./data/summary_401468653.json
# [json] events number:  444
# ...

# %%
actions = [event['type']['text'] for event in events]
actions = list(set(actions))
actions.sort()
print(len(actions))
# Out:
# 121

# %%
for action in actions:
    print(action)
# Out:
# 3-Second Turnover
# 5-Second Turnover
# 8-Second Turnover
# Alley Oop Dunk Shot
# Alley Oop Layup Shot
# Away from Play Foul
# Back Court Turnover
# Bad Pass
# Turnover
# Challenge
# Clear Path Foul
# Coach's Challenge (Overturned)
# Coach's Challenge (Stands)
# Coach's Challenge (Supported)
# Cutting Dunk Shot
# Cutting Finger Roll Layup Shot
# Cutting Layup Shot
# Defensive 3-Seconds Technical
# Defensive Goaltending
# Defensive Rebound
# Delay Technical
# Delay of Game
# Disc Dribble Turnover
# Double Dribble Turnover
# Double Lane
# Double Personal Foul
# Double Technical Foul
# Driving Dunk Shot
# Driving Finger Roll Layup
# Driving Floating Bank Jump Shot
# Driving Floating Jump Shot
# Driving Hook Shot
# Driving Jump Shot Bank
# Driving Layup Shot
# Driving Reverse Dunk Shot
# Dunk Shot
# Ejection
# End Game
# End Period
# Fade Away Bank Jump Shot
# Fade Away Jump Shot
# Finger Roll Layup
# Flagrant Foul Type 1
# Flagrant Foul Type 2
# Floating Jump Shot
# Free Throw - 1 of 1
# ...
